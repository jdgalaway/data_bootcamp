# %% [markdown]
# # Data Bootcamp Class #4

# %%
import pandas as pd

# %%
# This dictionary is similar to one that we saw earlier in the class
# It represents GDP/CPI data at 10 year intervals from 1990 to 2010
df = pd.DataFrame({"GDP": [5974.7, 10031.0, 14681.1],
                   "CPI": [127.5, 169.3, 217.488],
                   "Year": [1990, 2000, 2010],
                   "Country": ["US", "US", "US"]})

# %%
df #this will run our DataFrame which is similar to a spreadsheet
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
df.shape
# Out:
# (3, 4)

# %%
df.columns
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country'], dtype='object')

# %%
df.index #shape, columns and index are attributes of the DataFrame
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.T #transpose is also an attibute
# Out:
#               0      1        2
# GDP      5974.7  10031  14681.1
# CPI       127.5  169.3  217.488
# Year       1990   2000     2010
# Country      US     US       US

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
df.mean()
# Out:
# GDP     10228.933333
# CPI       171.429333
# Year     2000.000000
# dtype: float64

# %%
df.dtypes
# Out:
# GDP        float64
# CPI        float64
# Year         int64
# Country     object
# dtype: object

# %%
df.median(axis=1) #Axis=1 takes the median of the row while nothing or axis=0 will take the median of the column
# Out:
# 0    1990.0
# 1    2000.0
# 2    2010.0
# dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['GDP']
# Out:
# 0     5974.7
# 1    10031.0
# 2    14681.1
# Name: GDP, dtype: float64

# %%
type(df['GDP'])
# Out:
# pandas.core.series.Series

# %%
df['GDP'].mean()
# Out:
# 10228.933333333334

# %%
df.mean().sum() #You can
# Out:
# 12400.362666666668

# %%
df[['GDP', 'CPI', 'Year']].mean().sum()
# Out:
# 12400.362666666668

# %%
df.columns
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country'], dtype='object')

# %%
df.dtypes

# %%
dict(df.dtypes)
# Out:
# {'GDP': dtype('float64'),
#  'CPI': dtype('float64'),
#  'Year': dtype('int64'),
#  'Country': dtype('O')}

# %%
dict(df.dtypes).keys()
# Out:
# dict_keys(['GDP', 'CPI', 'Year', 'Country'])

# %%
numerical_vars = []   #complicated way
for i in dict(df.dtypes).keys():
    if dict(df.dtypes)[i]!='O':
        numerical_vars.append(i)
numerical_vars
# Out:
# ['GDP', 'CPI', 'Year']

# %%
numerical_vars = []   #complicated way
for i in df.columns:
    if df[i].dtype!='O':
        numerical_vars.append(i)
numerical_vars
# Out:
# ['GDP', 'CPI', 'Year']

# %%
[i for i in df.columns if df[i].dtype!='O'] #Easy way to get non objects on one line
# Out:
# ['GDP', 'CPI', 'Year']

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
 df2 = df.drop('Country',axis=1) #How to drop a column

# %%
df
# Out:
#        GDP      CPI  Year Country
# 0   5974.7  127.500  1990      US
# 1  10031.0  169.300  2000      US
# 2  14681.1  217.488  2010      US

# %%
df2
# Out:
#        GDP      CPI  Year
# 0   5974.7  127.500  1990
# 1  10031.0  169.300  2000
# 2  14681.1  217.488  2010

# %%
df.set_index('Year')
# Out:
#           GDP      CPI Country
# Year
# 1990   5974.7  127.500      US
# 2000  10031.0  169.300      US
# 2010  14681.1  217.488      US

# %%
df.set_index(['Country','Year'])
# Out:
#                   GDP      CPI
# Country Year
# US      1990   5974.7  127.500
#         2000  10031.0  169.300
#         2010  14681.1  217.488

# %%
df['rgdp'] = df['GDP']/(df['CPI']/100)

# %%
df
# Out:
#        GDP      CPI  Year Country         rgdp  cpi_base1
# 0   5974.7  127.500  1990      US  4686.039216    1.27500
# 1  10031.0  169.300  2000      US  5924.985233    1.69300
# 2  14681.1  217.488  2010      US  6750.303465    2.17488

# %%
df['cpi_base1'] = df['CPI']/100 #Called broadcasting

# %%
df
# Out:
#        GDP      CPI  Year Country       rgdp  cpi_base1
# 0   5974.7  127.500  1990      US  46.860392    1.27500
# 1  10031.0  169.300  2000      US  59.249852    1.69300
# 2  14681.1  217.488  2010      US  67.503035    2.17488

# %%
df = df.drop('cpi_base1',axis=1)

# %%
df
# Out:
#        GDP      CPI  Year Country         rgdp
# 0   5974.7  127.500  1990      US  4686.039216
# 1  10031.0  169.300  2000      US  5924.985233
# 2  14681.1  217.488  2010      US  6750.303465

# %%
df.rename(columns={'rgdp':'real_gdp'}) #rename a column
# Out:
#        GDP      CPI  Year Country     real_gdp
# 0   5974.7  127.500  1990      US  4686.039216
# 1  10031.0  169.300  2000      US  5924.985233
# 2  14681.1  217.488  2010      US  6750.303465

# %%
df.columns
# Out:
# Index(['GDP', 'CPI', 'Year', 'Country', 'rgdp'], dtype='object')

# %%
for i in df.columns:  #makes all column titles lower case
    df = df.rename(columns={i:i.lower()})
df
# Out:
#        gdp      cpi  year country         rgdp
# 0   5974.7  127.500  1990      US  4686.039216
# 1  10031.0  169.300  2000      US  5924.985233
# 2  14681.1  217.488  2010      US  6750.303465

# %%
for i in df.columns:  #makes all column titles upper case
    df = df.rename(columns={i:i.upper()})
df
# Out:
#        GDP      CPI  YEAR COUNTRY         RGDP
# 0   5974.7  127.500  1990      US  4686.039216
# 1  10031.0  169.300  2000      US  5924.985233
# 2  14681.1  217.488  2010      US  6750.303465

# %%
df.columns = [i.lower() for i in df.columns]

# %%
df
# Out:
#        gdp      cpi  year country         rgdp
# 0   5974.7  127.500  1990      US  4686.039216
# 1  10031.0  169.300  2000      US  5924.985233
# 2  14681.1  217.488  2010      US  6750.303465

# %% [markdown]
# # Read Data into Pandas/Python

# %%
import pandas as pd
import pandas_datareader as pdr
url1 = 'https://raw.githubusercontent.com/NYUDataBootcamp'
url2 = '/Materials/master/Data/test.csv'
url  = url1 + url2        # location of file
df = pd.read_csv(url)     # read file and assign it to df

# %%
#another way to read
df = pd.read_csv('https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/test.csv')

# %%
df
# Out:
#       name  x1  x2   x3
# 0     Dave   1   2  3.5
# 1    Chase   4   3  4.3
# 2  Spencer   5   6  7.8

# %%
df.to_excel('/Users/JD/Desktop/test.xlsx')

# %%
df.to_pickle('/Users/JD/Desktop/example.pkl')

# %%
url = 'https://www.rug.nl/ggdc/docs/pwt90.xlsx'
pwt = pd.read_excel(url, sheet_name='Data')

# %%
pwt
# Out:
#       countrycode   country   currency_unit  year         rgdpe         rgdpo  \
# 0             ABW     Aruba  Aruban Guilder  1950           NaN           NaN
# 1             ABW     Aruba  Aruban Guilder  1951           NaN           NaN
# 2             ABW     Aruba  Aruban Guilder  1952           NaN           NaN
# 3             ABW     Aruba  Aruban Guilder  1953           NaN           NaN
# 4             ABW     Aruba  Aruban Guilder  1954           NaN           NaN
# 5             ABW     Aruba  Aruban Guilder  1955           NaN           NaN
# 6             ABW     Aruba  Aruban Guilder  1956           NaN           NaN
# 7             ABW     Aruba  Aruban Guilder  1957           NaN           NaN
# 8             ABW     Aruba  Aruban Guilder  1958           NaN           NaN
# 9             ABW     Aruba  Aruban Guilder  1959           NaN           NaN
# 10            ABW     Aruba  Aruban Guilder  1960           NaN           NaN
# ...

# %%
url = 'http://dx.doi.org/10.1787/888932937035'
pisa = pd.read_excel(url,
                     skiprows=18,             # skip the first 18 rows
                     skipfooter=7,            # skip the last 7
                     parse_cols=[0,1,9,13],   # select columns of interest
                     index_col=0,             # set the index as the first column
                     header=[0,1]             # set the variable names
                     )
# Out:
# /Users/jd/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: the 'parse_cols' keyword is deprecated, use 'usecols' instead
#   import sys

# %%
pisa
# Out:
#                               Mathematics                  Reading    \
#                      Mean score in PISA 2012 Mean score in PISA 2012
# OECD average                      494.046447              496.462864
# NaN                                      NaN                     NaN
# Shanghai-China                    612.675536              569.588408
# Singapore                         573.468314              542.215834
# Hong Kong-China                   561.241096              544.600086
# Chinese Taipei                    559.824796              523.118904
# Korea                             553.766659              535.790490
# Macao-China                       538.134495              508.949255
# Japan                             536.406918              538.051485
# Liechtenstein                     534.965083              515.521654
# Switzerland                       530.931004              509.040250
# Netherlands                       522.971758              511.229965
# ...

# %%
pisa = pisa.dropna()                            # drop blank lines
pisa.columns = ['Math', 'Reading', 'Science']   # simplify variable names

# %%
pisa.columns
# Out:
# Index(['Math', 'Reading', 'Science'], dtype='object')

# %% [markdown]
# # errors for coding - encoding = "latin-1" and error.headliner=false
